# %%
import os
import networkx as nx
import rhinoinside
import logging
import nbimporter
from ghutilities import *
from icecream import ic
rhinoinside.load()
import Rhino
import clr
import sys
import System
import io
import csv
import pandas as pd
from IPython.display import display
import torch
from typing import Dict, List
import networkx as nx
import matplotlib.pyplot as plt
path = r"C:\Program Files\Rhino 8\Plug-ins\Grasshopper"
sys.path.append(path)
clr.AddReference("Grasshopper")
clr.AddReference("GH_IO")
clr.AddReference("GH_Util")
import Grasshopper
import Grasshopper.Kernel as ghk
from Grasshopper.Kernel import IGH_Component
from Grasshopper.Kernel import IGH_Param
import GH_IO
import GH_Util
from typing import Dict, List, Tuple

def get_ghdoc(filepath, filename):
    ghfile = os.path.join(filepath, filename)
    if not os.path.exists(ghfile):
        print("This file does not exists:", ghfile)
    ghdocIO = Grasshopper.Kernel.GH_DocumentIO()
    ghdocIO.Open(ghfile)
    ghdoc = ghdocIO.Document
    return ghdoc

filepath = os.getcwd()
filename = "test-BIG.gh"

d = get_ghdoc(filepath, filename)

# %%
class GHComponentProxy:
    """
    A class that represents an uninstantiated node component. This class is used to
    interface with the Grasshopper environment and manage component metadata.
    """
    component_server = Grasshopper.Instances.ComponentServer
    def __init__(self, obj_proxy: ghk.IGH_ObjectProxy):
        self.obj_proxy = obj_proxy
        self.category = str(obj_proxy.Desc.Category)
        self.name = str(obj_proxy.Desc.Name)
        self.guid = str(obj_proxy.Guid)
        self.nickname = str(obj_proxy.Desc.NickName)
        self.description = str(obj_proxy.Desc.Description)
        self.type = str(obj_proxy.Type)
        self.library = self.get_assembly_name()

    @property
    def sys_guid(self):
        return System.Guid(self.guid)

    @property
    def lib_guid(self):
        return self.obj_proxy.LibraryGuid

    def to_dict(self):
        return {
            "category": self.category,
            "name": self.name,
            "guid": self.guid,
            "nickname": self.nickname,
            "description": self.description[:60].replace("\n", " ").replace("\r", " ").strip(),
            "type": self.type,
            "library": self.library
        }

    def get_assembly(self) -> System.Reflection.Assembly:
        """
        Returns the AssemblyInfo object of a component. This method interfaces with
        the Grasshopper component server to retrieve assembly information.
        """
        return GHComponentProxy.component_server.FindAssembly(self.lib_guid)

    def get_assembly_name(self):
        """
        Retrieves the name of the assembly containing the component. This is used to
        identify the source library of the component.
        """
        assembly = self.get_assembly()
        return assembly.Name if assembly else "Unknown"

    def __str__(self):
        return f"{self.category}:{self.name}"

    def __repr__(self):
        return self.__str__()
    
class GHComponentTable:
    cs = Grasshopper.Instances.ComponentServer.ObjectProxies
    component_dict = {component.Guid: component for component in cs}
    vanilla_proxies = {}
    object_proxies = []
    non_native_proxies = []
    _guid_to_idx = {}
    _idx_to_guid = {}
    df = None

    @classmethod
    def initialise(cls):
        cls.vanilla_proxies = {obj.sys_guid: obj for obj in cls.load_vanilla_gh_proxies()}
        cls.object_proxies = [GHComponentProxy(obj) for obj in cls.cs]
        cls.non_native_proxies = sorted([ghp for ghp in cls.object_proxies if not cls.is_native(ghp) and not ghp.obj_proxy.Obsolete], key=lambda x: str(x))
        cls.object_proxies = list(cls.vanilla_proxies.values()) + cls.non_native_proxies
        cls.obj_lookup = {obj.sys_guid: obj for obj in cls.object_proxies}
        cls.df = cls.table_to_pandas()

    @classmethod
    def to_csv(cls, name="grasshopper_components.csv"):
        with open(name, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            if cls.object_proxies:
                header = cls.object_proxies[0].to_dict().keys()
                writer.writerow(header)
                for proxy in cls.object_proxies:
                    writer.writerow(proxy.to_dict().values())

    @classmethod
    def search_component_by_guid(cls, guid: System.Guid):
        return cls.component_dict[guid]

    @classmethod
    def is_native(cls, ghp):
        return cls.vanilla_proxies.get(ghp.sys_guid, False)

    @classmethod
    def convert_csv_line_to_proxies(cls, guid_str: str):
        guid = System.Guid(guid_str)
        proxy_object = cls.search_component_by_guid(guid)
        if proxy_object:
            logging.debug(f"Proxy object: {proxy_object.Desc.Name} found")
            return GHComponentProxy(proxy_object)
        logging.warning(f"Could not find a vanilla GH with guid {guid_str}")
        return None

    @classmethod
    def load_vanilla_gh_proxies(cls):
        vanilla_proxies = []
        with open('grasshopper_core_components.csv', mode='r') as cc:
            reader = csv.DictReader(cc)
            for row in reader:
                guid_str = row['guid']
                gh_proxy = cls.convert_csv_line_to_proxies(guid_str)
                if gh_proxy:
                    vanilla_proxies.append(gh_proxy)
        return vanilla_proxies

    @classmethod
    def view_all_categories(cls):
        categories = set([pr.category for pr in cls.object_proxies])
        print(f"There are {len(categories)} categories")
        print(categories)
        return categories

    @classmethod
    def view_proxies(cls, n):
        print(f"There are {len(cls.object_proxies)} proxies")
        for proxy in cls.object_proxies[:n]:
            print(proxy)

    @classmethod
    def table_to_pandas(cls):
        filename = 'grasshopper_components.csv'
        if not os.path.exists(filename):
            cls.to_csv(filename)
        df = pd.read_csv(filename)
        cls._guid_to_idx = {row[1]['guid']: row[0] for row in df.iterrows()}
        cls._idx_to_guid = {row[0]: row[1]['guid'] for row in df.iterrows()}
        return df

    @classmethod
    def get_guid_to_idx(cls, guid: System.Guid) -> int:
        return cls._guid_to_idx.get(str(guid), None)

    @classmethod
    def get_idx_to_guid(cls, idx: int) -> System.Guid:
        guid_str = cls._idx_to_guid.get(idx, None)
        return System.Guid(guid_str) if guid_str else None

    @classmethod
    def component_to_idx(cls, component) -> int:
        component = ghk.IGH_DocumentObject(component.obj)
        guid = component.ComponentGuid
        component_name = component.Name
        component_category = component.Category
        idx = cls.get_guid_to_idx(guid)
        if idx is not None:
            return idx
        guid_str = cls.df.where((cls.df['category'] == component_category) & (cls.df['name'] == component_name)).dropna().guid.iloc[0]
        if guid_str:
            idx = cls.get_guid_to_idx(System.Guid(guid_str))
            if idx:
                return idx
        logging.warning(f"ComponentTable.component_to_idx: Did not find the GUID or table match for {component_category}, {component_name}")
        return -1

    @classmethod
    def idx_to_component(cls, idx):
        return cls.df["nickname"].iloc[idx]

# %%
class GHNode:
    def __init__(self, obj, canvas=None):
        self.obj = obj
        self.canvas = canvas  # Canvas instance this node is part of
        self.category = obj.Category
        self.name = obj.Name
        self.id = str(obj.InstanceGuid)
        self.position = obj.Attributes.Pivot if hasattr(obj.Attributes, "Pivot") else None
        self.uid = f"{self.category}_{self.name}_{self.id[-5:]}"
        # Assuming global_idx is somehow related to GHComponentTable, which might need instance reference
        self.global_idx = GHComponentTable.component_to_idx(self)  # This requires GHComponentTable method adjustment
        self.graph_id = None

    def get_recipients(self):
        """To be implemented by the subclass"""
        pass

    def __str__(self):
        return f"{self.uid}"

    def __repr__(self):
        return self.__str__()

    def log_properties(self):
        log = {
            f"Category: {self.category}, "
            f"Name: {self.name}, "
            f"ID: {self.id[-5:]}, "
            f"Position: {self.position}"
            f"Global: {self.global_idx}"
        }
        # This method seems intended for logging or debugging, consider how it's used and adapt accordingly.

# %%
class GHParam:
   
    def __init__(self, obj):
        self.obj = obj
        self.parent = GHNode(ghk.IGH_DocumentObject(obj).Attributes.GetTopLevel.DocObject)
        self.name = obj.Name
        self.datamapping = int(obj.DataMapping) # enumerator 0:none, 1:Flatten, 2:Graft
        self.pkind = obj.Kind # the kind: floating (top level), input (parameter tied to component as input), output (parameter tied to a component as an output
        self.dataEmitter = obj.IsDataProvider # boolean stating whether this object is able to emit data
        # self.typ = obj.Type 
        self.typname = obj.TypeName # human-readable descriptor of this parameter
        self.optional = obj.Optional # gets whether this parameter is optional to the functioning of the component
        logging.info(f'GHComponent {self.parent.name} Params: {self.log_properties()}')
        
    @property
    def recipients(self):
        # if there are no recipents to this parameter, return none
        return [rcp for rcp in self.obj.Recipients] if len(self.obj.Recipients) > 0 else None
    
    @property
    def sources(self):
        # if there are no recipents to this parameter, return none
        return [rcp for rcp in self.obj.Sources] if len(self.obj.Sources) > 0 else None
    
    @property
    def data(self):
        return self.obj.VolatileData.DataDescription(False, False)
    
    def log_properties(self):
        properties = (
            f"Name: {self.name}, "
            f"DataMapping: {self.datamapping}, "
            f"Kind: {self.pkind}, "
            f"DataEmitter: {self.dataEmitter}, "
            f"TypeName: {self.typname}, "
            f"Optional: {self.optional}, "
            f"Data: {self.data}, "
        )
        return properties
    
    def __str__(self):
        repr_obj = ghk.IGH_DocumentObject(self.obj)
        return f"param:{self.name}"
    
    def __repr__(self):
        return self.__str__()

# %%
class GHComponent(GHNode):
    """Subclass of GHNode that handles GH components that implement IGH_Component.
    Each GHComponent object should contain a list of input parameter and output parameter objects.
    These parameter objects have access to the sources and recipients of the parameter"""

    def __init__(self, obj, canvas):
        super().__init__(obj, canvas)
        self.canvas = canvas
        self.iparams = None
        self.oparams = None
        self.recipients = None
        try:
            if self.category == "Params":
                self.obj = IGH_Param(obj)
                self.iparams = [GHParam(self.obj)]
                self.oparams = [GHParam(self.obj)]
            else:
                self.obj = IGH_Component(obj)
                self.iparams = [GHParam(p) for p in self.obj.Params.Input]
                self.oparams = [GHParam(p) for p in self.obj.Params.Output]
            self.recipients = [(param.name, [GHParam(p).parent for p in param.recipients]) for param in self.oparams if param.recipients is not None]
        except TypeError as e:
            logging.warning(f"COMPONENT {self.name},{self.id[-5:]}  failed initial assignment of parameters: {e}")
            try:
                self.obj = IGH_Param(obj)
                self.iparams = [GHParam(self.obj)]
                self.oparams = [GHParam(self.obj)]
                logging.info(f"COMPONENT {self.name},{self.id[-5:]} successfully assigned parameters: {self.iparams}, {self.oparams}")
            except TypeError as e:
                logging.warning(f"COMPONENT {self.name},{self.id[-5:]} DID NOT EXTRACT PARAMETERS, not added to components table")
                print(f"DID NOT ADD {self.name}")
        # self.iparams_dict = {k.name: i for i, k in enumerate(self.iparams)}
        # self.oparams_dict = {k.name: i for i, k in enumerate(self.oparams)}


    def get_connections(self):
        """Returns the source and recipient connections for this component"""

        source_connections = []
        recipient_connections = []

        # Handle connections to recipients from this component's output parameters
        for i, oparam in enumerate(self.oparams):  # Iterate over output parameters
            if oparam.recipients:  # Ensure there are recipients to consider
                for r in oparam.recipients:
                    recipient = GHParam(r)
                    recipient_component = GHComponent(recipient.parent.obj, self.canvas)
                    parent_instance = self.canvas.find_object_by_guid(recipient_component.id)
                    recipient_parameter_index = recipient_component.iparams_dict.get(recipient.name)

                    recipient_conn = {
                        'to': parent_instance,
                        'edge': (i, recipient_parameter_index)
                    }
                    recipient_connections.append(recipient_conn)

        # Handle connections from sources to this component's input parameters
        for i, iparam in enumerate(self.iparams):  # Iterate over input parameters
            if iparam.sources:  # Ensure there are sources to consider
                for s in iparam.sources:
                    source = GHParam(s)
                    source_component = GHComponent(source.parent.obj, self.canvas)
                    source_instance = self.canvas.find_object_by_guid(source_component.id)
                    source_parameter_index = source_component.oparams_dict.get(source.name)  # Assuming oparams_dict includes source name

                    source_conn = {
                        'from': source_instance,
                        'edge': (source_parameter_index, i)
                    }
                    source_connections.append(source_conn)

        return source_connections, recipient_connections

    def __str__(self):
        return f"{self.name} ({self.category})"

    def __repr__(self):
        return self.__str__()

# %%
# from abc import ABC, abstractmethod
# class CanvasInterface(ABC):
#     
#     @classmethod
#     @abstractmethod
#     def initialize(cls, doc):
#         raise NotImplementedError
#     
#     @classmethod
#     @abstractmethod
# 
#     def find_object_by_guid(cls, guid):
#         raise NotImplementedError
#     
# class Canvas(CanvasInterface):
#     doc = None
#     components = None
#     guid_to_component = None
#     
#     @classmethod
#     def initialize(cls, doc):
#         cls.doc = doc
#         cls.components = [GHComponent(o) for o in list(doc.Objects)]
#         cls.guid_to_component = {c.id : c for c in cls.components}
# 
#     @classmethod
#     def find_object_by_guid(cls, guid:str) -> GHComponent:
#         return cls.guid_to_component.get(guid)
# 
# 
# class ComponentTableInterface(ABC):
#     
#     @classmethod
#     @abstractmethod
#     def initialize(cls):
#         """
#         Initializes the component table, loading components and proxies.
#         """
#         raise NotImplementedError
# 
#     @classmethod
#     @abstractmethod
#     def to_csv(cls, name):
#         """
#         Exports the component information to a CSV file.
#         """
#         raise NotImplementedError
# 
#     @classmethod
#     @abstractmethod
#     def search_component_by_guid(cls, guid):
#         """
#         Searches for a component by its GUID.
#         """
#         raise NotImplementedError
# 
#     @classmethod
#     @abstractmethod
#     def load_vanilla_gh_proxies(cls):
#         """
#         Loads the vanilla Grasshopper components from a CSV or similar source.
#         """
#         raise NotImplementedError
# 
#     @classmethod
#     @abstractmethod
#     def get_guid_to_idx(cls, guid) -> int:
#         """
#         Gets the index of a component based on its GUID.
#         """
#         raise NotImplementedError
# 
#     @classmethod
#     @abstractmethod
#     def get_idx_to_guid(cls, idx) -> str:
#         """
#         Gets the GUID of a component based on its index.
#         """
#         raise NotImplementedError
# 
#     @classmethod
#     @abstractmethod
#     def component_to_idx(cls, component) -> int:
#         """
#         Converts a component to its index in the table.
#         """
#         raise NotImplementedError
# 
#     @classmethod
#     @abstractmethod
#     def idx_to_component(cls, idx):
#         """
#         Retrieves a component based on its index in the table.
#         """
#         raise NotImplementedError

# %%
class Canvas:
    def __init__(self, doc, n = None):
        GHComponentTable.initialise()
        self.doc = doc
        self.components = []  # Initialize as empty
        self.guid_to_component = {}  # Initialize as empty
        self.initialize_components(n)


    def initialize_components(self, n=None):
        if n:
            self.components = [GHComponent(o, self) for o in list(self.doc.Objects)[:n]]
            self.guid_to_component = {c.id: c for c in self.components}
        else:
            self.components = [GHComponent(o, self) for o in list(self.doc.Objects)]
            self.guid_to_component = {c.id: c for c in self.components}

    def find_object_by_guid(self, guid:str) -> GHComponent:
        return self.guid_to_component.get(guid)
    
    # def process_mappings(self):
    #     idx_set = set([component.global_idx for component in self.components])
    #     idx_lookup = {K : [] for K in idx_set}
    #     graph_id_to_component = {}
    #     # ensure there are still incremeting the size of the list
    #     for component in self.components:
    #         component_table_idx = GHComponentTable.component_to_idx(component)
    #         existing_list = idx_lookup[component_table_idx]
    #         x = (component.global_idx, len(existing_list))
    #         existing_list.append(x)
    #         component.graph_id = x
    #         graph_id_to_component[component.graph_id] = component       
    #     return graph_id_to_component

# %%
c = Canvas(d)
# Out:
# WARNING:root:COMPONENT Point,62460  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Point,62460 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Range,dee50  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Range,dee50 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Range,378d4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Range,378d4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,f64a4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,f64a4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,c4914  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,c4914 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Rotate,ad8b3  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Rotate,ad8b3 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,33c49  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,33c49 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Construct Domain,160d7  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Construct Domain,160d7 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,0969d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,0969d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Nurbs Curve,a1265  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Nurbs Curve,a1265 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Nurbs Curve,d8033  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Nurbs Curve,d8033 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,37597  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,37597 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Cross Product,2e417  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Cross Product,2e417 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,7b6f4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,7b6f4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Vector Display,2b3dc  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Vector Display,2b3dc DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Project Point,ee347  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Project Point,ee347 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode Tree,70659  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode Tree,70659 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,06ea4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,06ea4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve Closest Point,b51a2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve Closest Point,b51a2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Shatter,2d2b9  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Shatter,2d2b9 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT List Item,e073f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT List Item,e073f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Length,20010  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Length,20010 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Sort List,1c57c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Sort List,1c57c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,bb70a  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,bb70a DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Line,c0244  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Line,c0244 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Graph Mapper,3a25b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Graph Mapper,3a25b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,9fbac  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,9fbac DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Range,16c18  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Range,16c18 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Remap Numbers,cfcd0  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Remap Numbers,cfcd0 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Bounds,e2a86  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Bounds,e2a86 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Construct Domain,7ca89  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Construct Domain,7ca89 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,f361e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,f361e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,b371b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,b371b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Addition,960d6  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Addition,960d6 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,0ffd5  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,0ffd5 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Horizontal Frames,c6e19  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Horizontal Frames,c6e19 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct Plane,42ca5  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct Plane,42ca5 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Project Point,1dd79  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Project Point,1dd79 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,3480f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,3480f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Pi,fd135  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Pi,fd135 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,cbb74  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,cbb74 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Scale NU,a3c11  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Scale NU,a3c11 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT XY Plane,7331e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT XY Plane,7331e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Rotate Plane,8f00f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Rotate Plane,8f00f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,7acd8  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,7acd8 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,113f8  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,113f8 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,bdc06  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,bdc06 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,a3405  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,a3405 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,83850  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,83850 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,4bd67  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,4bd67 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,d6f75  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,d6f75 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Region Union,73083  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Region Union,73083 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT List Item,e4418  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT List Item,e4418 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Area,fce63  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Area,fce63 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Sort List,cfcca  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Sort List,cfcca DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Boundary Surfaces,7c6e7  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Boundary Surfaces,7c6e7 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Custom Preview,906ff  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Custom Preview,906ff DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,63519  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,63519 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT End Points,bf44e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT End Points,bf44e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,388f2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,388f2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode,c56be  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode,c56be DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Match Text,c8d8d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Match Text,c8d8d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,5c96c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,5c96c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,5a831  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,5a831 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Cull Pattern,88036  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Cull Pattern,88036 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Interpolate,1ac9f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Interpolate,1ac9f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode,18155  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode,18155 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,c8ade  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,c8ade DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Match Text,77e9b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Match Text,77e9b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,4385b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,4385b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Dispatch,4b805  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Dispatch,4b805 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,426cb  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,426cb DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,4a9fc  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,4a9fc DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,a47e3  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,a47e3 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,d6222  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,d6222 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,00e1b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,00e1b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Path Mapper,6d275  failed initial assignment of parameters: object does not implement IGH_Component
# WARNING:root:COMPONENT Path Mapper,6d275 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,746bf  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,746bf DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Path Mapper,6f03f  failed initial assignment of parameters: object does not implement IGH_Component
# WARNING:root:COMPONENT Path Mapper,6f03f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,a2e94  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,a2e94 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,93794  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,93794 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT End Points,f624c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT End Points,f624c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Project,09411  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Project,09411 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Merge,4aaa1  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Merge,4aaa1 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT XY Plane,23210  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT XY Plane,23210 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Line,0c261  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Line,0c261 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Merge,c799e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Merge,c799e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Join Curves,04899  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Join Curves,04899 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode Tree,3b7ce  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode Tree,3b7ce DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface,3245d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface,3245d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface,1d46e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface,1d46e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface,0327e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface,0327e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface,5eea2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface,5eea2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Interpolate,1bc79  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Interpolate,1bc79 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode Tree,f9c9a  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode Tree,f9c9a DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,2cf5d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,2cf5d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode Tree,0ec42  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode Tree,0ec42 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,2a64e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,2a64e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,87706  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,87706 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Merge,417cf  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Merge,417cf DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Join Curves,b2e68  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Join Curves,b2e68 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,c3568  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,c3568 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,dc016  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,dc016 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface Split,1998a  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface Split,1998a DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,6acdd  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,6acdd DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,5e99e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,5e99e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,7307c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,7307c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,009e0  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,009e0 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Reverse,3ff42  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Reverse,3ff42 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,b747c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,b747c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Extrude,14436  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Extrude,14436 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,cee3c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,cee3c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct Brep,1bc49  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct Brep,1bc49 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Pull Point,0433b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Pull Point,0433b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Larger Than,d3400  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Larger Than,d3400 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Multiplication,c4acf  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Multiplication,c4acf DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,46cca  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,46cca DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Sort List,a2a74  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Sort List,a2a74 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT List Item,de9c2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT List Item,de9c2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Cull Pattern,5de94  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Cull Pattern,5de94 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Graft Tree,349db  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Graft Tree,349db DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct,24f95  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct,24f95 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct,50399  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct,50399 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Point,1d263  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Point,1d263 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Mass Addition,d5fbd  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Mass Addition,d5fbd DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Equality,aa4b4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Equality,aa4b4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Boolean,bcb7e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Boolean,bcb7e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Gate Or,6d9e5  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Gate Or,6d9e5 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Colour Swatch,6e962  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Colour Swatch,6e962 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Merge,436fb  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Merge,436fb DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Brep Join,64dc6  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Brep Join,64dc6 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number,e3a8e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number,e3a8e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Point Cylindrical,c98a3  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Point Cylindrical,c98a3 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Colour Swatch,e33d2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Colour Swatch,e33d2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,f482c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,f482c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Evaluate Curve,454ef  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Evaluate Curve,454ef DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Custom Preview,4d65f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Custom Preview,4d65f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT XY Plane,7a687  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT XY Plane,7a687 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,e87b6  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,e87b6 DID NOT EXTRACT PARAMETERS, not added to components table
# DID NOT ADD Point
# DID NOT ADD Range
# DID NOT ADD Range
# DID NOT ADD Number Slider
# DID NOT ADD Number Slider
# DID NOT ADD Rotate
# DID NOT ADD Panel
# DID NOT ADD Construct Domain
# DID NOT ADD Number Slider
# DID NOT ADD Nurbs Curve
# DID NOT ADD Nurbs Curve
# DID NOT ADD Entwine
# DID NOT ADD Cross Product
# DID NOT ADD Unit Z
# DID NOT ADD Vector Display
# DID NOT ADD Project Point
# DID NOT ADD Explode Tree
# DID NOT ADD Entwine
# DID NOT ADD Curve Closest Point
# DID NOT ADD Shatter
# DID NOT ADD List Item
# DID NOT ADD Length
# DID NOT ADD Sort List
# DID NOT ADD Number Slider
# DID NOT ADD Line
# DID NOT ADD Graph Mapper
# DID NOT ADD Panel
# DID NOT ADD Range
# DID NOT ADD Remap Numbers
# DID NOT ADD Bounds
# DID NOT ADD Construct Domain
# DID NOT ADD Number Slider
# DID NOT ADD Unit Z
# DID NOT ADD Addition
# DID NOT ADD Number Slider
# DID NOT ADD Horizontal Frames
# DID NOT ADD Deconstruct Plane
# DID NOT ADD Project Point
# DID NOT ADD Number Slider
# DID NOT ADD Pi
# DID NOT ADD Number Slider
# DID NOT ADD Scale NU
# DID NOT ADD XY Plane
# DID NOT ADD Rotate Plane
# DID NOT ADD Number Slider
# DID NOT ADD Number Slider
# DID NOT ADD Number Slider
# DID NOT ADD Curve
# DID NOT ADD Move
# DID NOT ADD Loft
# DID NOT ADD Loft
# DID NOT ADD Region Union
# DID NOT ADD List Item
# DID NOT ADD Area
# DID NOT ADD Sort List
# DID NOT ADD Boundary Surfaces
# DID NOT ADD Custom Preview
# DID NOT ADD Unit Z
# DID NOT ADD End Points
# DID NOT ADD Curve
# DID NOT ADD Explode
# DID NOT ADD Match Text
# DID NOT ADD Panel
# DID NOT ADD Panel
# DID NOT ADD Cull Pattern
# DID NOT ADD Interpolate
# DID NOT ADD Explode
# DID NOT ADD Panel
# DID NOT ADD Match Text
# DID NOT ADD Panel
# DID NOT ADD Dispatch
# DID NOT ADD Curve
# DID NOT ADD Curve
# DID NOT ADD Entwine
# DID NOT ADD Loft
# DID NOT ADD Curve
# DID NOT ADD Path Mapper
# DID NOT ADD Loft
# DID NOT ADD Path Mapper
# DID NOT ADD Loft
# DID NOT ADD Move
# DID NOT ADD End Points
# DID NOT ADD Project
# DID NOT ADD Merge
# DID NOT ADD XY Plane
# DID NOT ADD Line
# DID NOT ADD Merge
# DID NOT ADD Join Curves
# DID NOT ADD Explode Tree
# DID NOT ADD Surface
# DID NOT ADD Surface
# DID NOT ADD Surface
# DID NOT ADD Surface
# DID NOT ADD Interpolate
# DID NOT ADD Explode Tree
# DID NOT ADD Curve
# DID NOT ADD Explode Tree
# DID NOT ADD Curve
# DID NOT ADD Curve
# DID NOT ADD Merge
# DID NOT ADD Join Curves
# DID NOT ADD Entwine
# DID NOT ADD Curve
# DID NOT ADD Surface Split
# DID NOT ADD Move
# DID NOT ADD Unit Z
# DID NOT ADD Number Slider
# DID NOT ADD Move
# DID NOT ADD Reverse
# DID NOT ADD Unit Z
# DID NOT ADD Extrude
# DID NOT ADD Unit Z
# DID NOT ADD Deconstruct Brep
# DID NOT ADD Pull Point
# DID NOT ADD Larger Than
# DID NOT ADD Multiplication
# DID NOT ADD Number Slider
# DID NOT ADD Sort List
# DID NOT ADD List Item
# DID NOT ADD Cull Pattern
# DID NOT ADD Graft Tree
# DID NOT ADD Deconstruct
# DID NOT ADD Deconstruct
# DID NOT ADD Point
# DID NOT ADD Mass Addition
# DID NOT ADD Equality
# DID NOT ADD Boolean
# DID NOT ADD Gate Or
# DID NOT ADD Colour Swatch
# DID NOT ADD Merge
# DID NOT ADD Brep Join
# DID NOT ADD Number
# DID NOT ADD Point Cylindrical
# DID NOT ADD Colour Swatch
# DID NOT ADD Panel
# DID NOT ADD Evaluate Curve
# DID NOT ADD Custom Preview
# DID NOT ADD XY Plane
# DID NOT ADD Panel

# %%
class GraphConnection:
    def __init__(self, v1n, v1i, v2n, v2i, edge):
        self.v1n = v1n
        self.v1i = v1i
        self.v2n = v2n
        self.v2i = v2i
        self.e1 = edge[0]
        self.e2 = edge[1]
        self.tensor = torch.tensor([self.v1n, self.v1i, self.e1, self.v2n, self.v2i, self.e2], dtype=torch.int16)
    
    def __str__(self):
        return f"GC({self.v1n}-{self.v1i}, {self.v2n}-{self.v2i})"
    
    def __repr__(self):
        return str(self.tensor)

# %%
# class Graph_Node:
#     def __init__(self, component: GHComponent, idx: int):
#         self.component = component  # GHComponent instance
#         self.graph_id = component.graph_id
#         self.sources, self.recipients = self.component.get_connections()  # Adjust get_connections method as needed
#         self.connections = self.get_graph_connections()
# 
#     def get_numbering(self, graph_id) -> Tuple[int, int]:
#         """Safely gets the graph numbering, defaulting to -1 if the graph_id is None."""
#         return self.component_id, self.idx
# 
#     def get_graph_connections(self):
#             graph_connections = {
#                 "sources": [],
#                 "recipients": []
#             }
#             # Process recipient connections (outgoing)
#             for connection in self.recipients:
#                 v2 = connection.get("to")
#                 v1n, v1i = 
#                 v2n, v2i = self.get_numbering(v2.graph_id)
#                 edge = connection.get("edge")
#                 graph_connections["recipients"].append(GraphConnection(v1n, v1i, v2n, v2i, edge))
# 
#             # Process source connections (incoming)
#             for connection in self.sources:
#                 v1 = connection.get("from")
#                 v1n, v1i = self.get_numbering(v1.graph_id if v1 else None)
#                 v2n, v2i = self.get_numbering(self.id)  # For incoming, self.id is the destination
#                 edge = [int(x) for x in connection.get("edge")]
#                 graph_connections["sources"].append(GraphConnection(v1n, v1i, v2n, v2i, edge))
# 
#             return graph_connections
# 
#     def __str__(self):
#         return f"{self.component.global_idx}-{self.idx}"
# 
#     def __repr__(self):
#         return self.__str__()

class GHNode:
    def __init__(self, graph_id, canvas):
        self.graph_id = graph_id
        self.component = canvas.graph_id_to_component(graph_id)
    
    @property
    def edges(self):
         ic(self.component.connections['recipients'])
    
        


class GHGraph:
    def __init__(self, canvas):
        self.canvas = canvas
        self.components = self.canvas.components
                
    @property
    def nodes(self) -> List[GHNode]:
        return [GHNode(component.graph_id, self.canvas) for component in self.components]
    
    
    
    
    # @property
    # def edges(self):
    #     edgs: List[GraphConnection] = []
    #     for node in self.nodes:
    #         for con in node.connections["recipients"]:
    #             edgs.append(con)
    #     return edgs
    # 
    # @property
    # def edge_tensor(self):
    #     return torch.stack([edge.tensor for edge in self.edges], dim=0)
    # 
    # def create_component_mappings(self):
    #     component_count_map = {}
    #     idx_set = set([component.global_idx for component in self.components])
    #     idx_lookup = {K : [] for K in idx_set}
    #     for component in self.components:
    #         component_table_idx = GHComponentTable.component_to_idx(component)
    #         existing_list = idx_lookup[component_table_idx]
    #         existing_list.append(Graph_Node(component, len(existing_list)))
    #         idx_lookup[component_table_idx] = existing_list
    #     return idx_lookup
    # 
    # 
    # def nxGraph(self):
    #     plt.figure(figsize=(20, 20))
    #     gx = nx.Graph()  # Initialize the graph
    #     edges = []
    #     for con in self.edges:
    #         x  = (f"{con.v1n}-{con.v1i}", f"{con.v2n}-{con.v2i}")
    #         edges.append(x)
    #     # edges = [ for con in self.edges]  # Build edges
    #     gx.add_edges_from(edges)  # Add edges to the graph correctly
    #     return gx
    # 
    # def show_graph(self):
    #     plt.figure(figsize=(12, 8))  # Adjust the figure size as desired
    #     gx = self.nxGraph()
    # 
    #     # Define custom labels for nodes to use only the part before the hyphen
    #     custom_labels = {node: GHComponentTable.idx_to_component(int(node.split('-')[0])) for node in gx.nodes()}
    #     nans = [custom_labels.items()]
    #     nx.draw(gx, with_labels=True, labels=custom_labels, node_size=1000, font_size=10)
    #     plt.show()
    # 
    # 
    # def save_graph(self, filename):
    #     gx = self.nxGraph()
    #     nx.write_graphml(gx, filename)
    #     
    # def save_graph_png(self, filename):
    #     gx = self.nxGraph()
    #     custom_labels = {node: GHComponentTable.idx_to_component(int(node.split('-')[0])) for node in gx.nodes()}
    #     nans = [custom_labels.items()]
    #     nx.draw(gx, with_labels=True, labels=custom_labels, node_size=1000, font_size=10)
    #     plt.savefig(filename + "png")
    # 
    # def __str__(self):
    #     
    #     return f"{self.edges}"

# %%
canvas = Canvas(d)
comps = canvas.components
# graph = GHGraph(canvas)
# graph.nodes
# Out:
# WARNING:root:COMPONENT Point,62460  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Point,62460 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Range,dee50  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Range,dee50 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Range,378d4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Range,378d4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,f64a4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,f64a4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,c4914  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,c4914 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Rotate,ad8b3  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Rotate,ad8b3 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,33c49  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,33c49 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Construct Domain,160d7  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Construct Domain,160d7 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,0969d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,0969d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Nurbs Curve,a1265  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Nurbs Curve,a1265 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Nurbs Curve,d8033  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Nurbs Curve,d8033 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,37597  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,37597 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Cross Product,2e417  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Cross Product,2e417 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,7b6f4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,7b6f4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Vector Display,2b3dc  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Vector Display,2b3dc DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Project Point,ee347  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Project Point,ee347 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode Tree,70659  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode Tree,70659 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,06ea4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,06ea4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve Closest Point,b51a2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve Closest Point,b51a2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Shatter,2d2b9  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Shatter,2d2b9 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT List Item,e073f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT List Item,e073f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Length,20010  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Length,20010 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Sort List,1c57c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Sort List,1c57c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,bb70a  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,bb70a DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Line,c0244  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Line,c0244 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Graph Mapper,3a25b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Graph Mapper,3a25b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,9fbac  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,9fbac DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Range,16c18  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Range,16c18 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Remap Numbers,cfcd0  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Remap Numbers,cfcd0 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Bounds,e2a86  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Bounds,e2a86 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Construct Domain,7ca89  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Construct Domain,7ca89 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,f361e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,f361e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,b371b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,b371b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Addition,960d6  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Addition,960d6 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,0ffd5  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,0ffd5 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Horizontal Frames,c6e19  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Horizontal Frames,c6e19 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct Plane,42ca5  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct Plane,42ca5 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Project Point,1dd79  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Project Point,1dd79 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,3480f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,3480f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Pi,fd135  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Pi,fd135 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,cbb74  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,cbb74 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Scale NU,a3c11  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Scale NU,a3c11 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT XY Plane,7331e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT XY Plane,7331e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Rotate Plane,8f00f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Rotate Plane,8f00f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,7acd8  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,7acd8 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,113f8  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,113f8 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,bdc06  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,bdc06 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,a3405  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,a3405 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,83850  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,83850 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,4bd67  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,4bd67 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,d6f75  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,d6f75 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Region Union,73083  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Region Union,73083 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT List Item,e4418  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT List Item,e4418 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Area,fce63  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Area,fce63 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Sort List,cfcca  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Sort List,cfcca DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Boundary Surfaces,7c6e7  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Boundary Surfaces,7c6e7 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Custom Preview,906ff  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Custom Preview,906ff DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,63519  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,63519 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT End Points,bf44e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT End Points,bf44e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,388f2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,388f2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode,c56be  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode,c56be DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Match Text,c8d8d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Match Text,c8d8d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,5c96c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,5c96c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,5a831  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,5a831 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Cull Pattern,88036  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Cull Pattern,88036 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Interpolate,1ac9f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Interpolate,1ac9f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode,18155  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode,18155 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,c8ade  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,c8ade DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Match Text,77e9b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Match Text,77e9b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,4385b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,4385b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Dispatch,4b805  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Dispatch,4b805 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,426cb  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,426cb DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,4a9fc  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,4a9fc DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,a47e3  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,a47e3 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,d6222  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,d6222 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,00e1b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,00e1b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Path Mapper,6d275  failed initial assignment of parameters: object does not implement IGH_Component
# WARNING:root:COMPONENT Path Mapper,6d275 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,746bf  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,746bf DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Path Mapper,6f03f  failed initial assignment of parameters: object does not implement IGH_Component
# WARNING:root:COMPONENT Path Mapper,6f03f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,a2e94  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,a2e94 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,93794  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,93794 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT End Points,f624c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT End Points,f624c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Project,09411  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Project,09411 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Merge,4aaa1  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Merge,4aaa1 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT XY Plane,23210  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT XY Plane,23210 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Line,0c261  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Line,0c261 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Merge,c799e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Merge,c799e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Join Curves,04899  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Join Curves,04899 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode Tree,3b7ce  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode Tree,3b7ce DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface,3245d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface,3245d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface,1d46e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface,1d46e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface,0327e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface,0327e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface,5eea2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface,5eea2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Interpolate,1bc79  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Interpolate,1bc79 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode Tree,f9c9a  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode Tree,f9c9a DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,2cf5d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,2cf5d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode Tree,0ec42  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode Tree,0ec42 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,2a64e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,2a64e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,87706  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,87706 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Merge,417cf  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Merge,417cf DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Join Curves,b2e68  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Join Curves,b2e68 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,c3568  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,c3568 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,dc016  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,dc016 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface Split,1998a  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface Split,1998a DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,6acdd  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,6acdd DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,5e99e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,5e99e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,7307c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,7307c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,009e0  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,009e0 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Reverse,3ff42  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Reverse,3ff42 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,b747c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,b747c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Extrude,14436  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Extrude,14436 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,cee3c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,cee3c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct Brep,1bc49  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct Brep,1bc49 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Pull Point,0433b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Pull Point,0433b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Larger Than,d3400  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Larger Than,d3400 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Multiplication,c4acf  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Multiplication,c4acf DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,46cca  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,46cca DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Sort List,a2a74  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Sort List,a2a74 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT List Item,de9c2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT List Item,de9c2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Cull Pattern,5de94  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Cull Pattern,5de94 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Graft Tree,349db  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Graft Tree,349db DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct,24f95  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct,24f95 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct,50399  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct,50399 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Point,1d263  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Point,1d263 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Mass Addition,d5fbd  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Mass Addition,d5fbd DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Equality,aa4b4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Equality,aa4b4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Boolean,bcb7e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Boolean,bcb7e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Gate Or,6d9e5  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Gate Or,6d9e5 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Colour Swatch,6e962  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Colour Swatch,6e962 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Merge,436fb  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Merge,436fb DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Brep Join,64dc6  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Brep Join,64dc6 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number,e3a8e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number,e3a8e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Point Cylindrical,c98a3  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Point Cylindrical,c98a3 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Colour Swatch,e33d2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Colour Swatch,e33d2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,f482c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,f482c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Evaluate Curve,454ef  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Evaluate Curve,454ef DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Custom Preview,4d65f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Custom Preview,4d65f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT XY Plane,7a687  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT XY Plane,7a687 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,e87b6  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,e87b6 DID NOT EXTRACT PARAMETERS, not added to components table
# DID NOT ADD Point
# DID NOT ADD Range
# DID NOT ADD Range
# DID NOT ADD Number Slider
# DID NOT ADD Number Slider
# DID NOT ADD Rotate
# DID NOT ADD Panel
# DID NOT ADD Construct Domain
# DID NOT ADD Number Slider
# DID NOT ADD Nurbs Curve
# DID NOT ADD Nurbs Curve
# DID NOT ADD Entwine
# DID NOT ADD Cross Product
# DID NOT ADD Unit Z
# DID NOT ADD Vector Display
# DID NOT ADD Project Point
# DID NOT ADD Explode Tree
# DID NOT ADD Entwine
# DID NOT ADD Curve Closest Point
# DID NOT ADD Shatter
# DID NOT ADD List Item
# DID NOT ADD Length
# DID NOT ADD Sort List
# DID NOT ADD Number Slider
# DID NOT ADD Line
# DID NOT ADD Graph Mapper
# DID NOT ADD Panel
# DID NOT ADD Range
# DID NOT ADD Remap Numbers
# DID NOT ADD Bounds
# DID NOT ADD Construct Domain
# DID NOT ADD Number Slider
# DID NOT ADD Unit Z
# DID NOT ADD Addition
# DID NOT ADD Number Slider
# DID NOT ADD Horizontal Frames
# DID NOT ADD Deconstruct Plane
# DID NOT ADD Project Point
# DID NOT ADD Number Slider
# DID NOT ADD Pi
# DID NOT ADD Number Slider
# DID NOT ADD Scale NU
# DID NOT ADD XY Plane
# DID NOT ADD Rotate Plane
# DID NOT ADD Number Slider
# DID NOT ADD Number Slider
# DID NOT ADD Number Slider
# DID NOT ADD Curve
# DID NOT ADD Move
# DID NOT ADD Loft
# DID NOT ADD Loft
# DID NOT ADD Region Union
# DID NOT ADD List Item
# DID NOT ADD Area
# DID NOT ADD Sort List
# DID NOT ADD Boundary Surfaces
# DID NOT ADD Custom Preview
# DID NOT ADD Unit Z
# DID NOT ADD End Points
# DID NOT ADD Curve
# DID NOT ADD Explode
# DID NOT ADD Match Text
# DID NOT ADD Panel
# DID NOT ADD Panel
# DID NOT ADD Cull Pattern
# DID NOT ADD Interpolate
# DID NOT ADD Explode
# DID NOT ADD Panel
# DID NOT ADD Match Text
# DID NOT ADD Panel
# DID NOT ADD Dispatch
# DID NOT ADD Curve
# DID NOT ADD Curve
# DID NOT ADD Entwine
# DID NOT ADD Loft
# DID NOT ADD Curve
# DID NOT ADD Path Mapper
# DID NOT ADD Loft
# DID NOT ADD Path Mapper
# DID NOT ADD Loft
# DID NOT ADD Move
# DID NOT ADD End Points
# DID NOT ADD Project
# DID NOT ADD Merge
# DID NOT ADD XY Plane
# DID NOT ADD Line
# DID NOT ADD Merge
# DID NOT ADD Join Curves
# DID NOT ADD Explode Tree
# DID NOT ADD Surface
# DID NOT ADD Surface
# DID NOT ADD Surface
# DID NOT ADD Surface
# DID NOT ADD Interpolate
# DID NOT ADD Explode Tree
# DID NOT ADD Curve
# DID NOT ADD Explode Tree
# DID NOT ADD Curve
# DID NOT ADD Curve
# DID NOT ADD Merge
# DID NOT ADD Join Curves
# DID NOT ADD Entwine
# DID NOT ADD Curve
# DID NOT ADD Surface Split
# DID NOT ADD Move
# DID NOT ADD Unit Z
# DID NOT ADD Number Slider
# DID NOT ADD Move
# DID NOT ADD Reverse
# DID NOT ADD Unit Z
# DID NOT ADD Extrude
# DID NOT ADD Unit Z
# DID NOT ADD Deconstruct Brep
# DID NOT ADD Pull Point
# DID NOT ADD Larger Than
# DID NOT ADD Multiplication
# DID NOT ADD Number Slider
# DID NOT ADD Sort List
# DID NOT ADD List Item
# DID NOT ADD Cull Pattern
# DID NOT ADD Graft Tree
# DID NOT ADD Deconstruct
# DID NOT ADD Deconstruct
# DID NOT ADD Point
# DID NOT ADD Mass Addition
# DID NOT ADD Equality
# DID NOT ADD Boolean
# DID NOT ADD Gate Or
# DID NOT ADD Colour Swatch
# DID NOT ADD Merge
# DID NOT ADD Brep Join
# DID NOT ADD Number
# DID NOT ADD Point Cylindrical
# DID NOT ADD Colour Swatch
# DID NOT ADD Panel
# DID NOT ADD Evaluate Curve
# DID NOT ADD Custom Preview
# DID NOT ADD XY Plane
# DID NOT ADD Panel

# %%
# class GHGraph:
#     def __init__(self, canvas):
#         self.canvas = canvas
#         self.components = self.canvas.components
#         self.component_mapping = self.create_component_mappings()
#         # The _graphnodes attribute will store Graph_Node instances, which represent the nodes in our graph.
#         self._graphnodes = [v for lst in self.component_mapping.values() for v in lst]
# 
#                 
#     @property
#     def nodes(self):
#         return self._graphnodes
#     
#     @property
#     def edges(self):
#         edgs: List[GraphConnection] = []
#         for node in self.nodes:
#             for con in node.connections["recipients"]:
#                 edgs.append(con)
#         return edgs
#     
#     @property
#     def edge_tensor(self):
#         return torch.stack([edge.tensor for edge in self.edges], dim=0)
#     
#     def create_component_mappings(self):
#         component_count_map = {}
#         idx_set = set([component.global_idx for component in self.components])
#         idx_lookup = {K : [] for K in idx_set}
#         for component in self.components:
#             component_table_idx = GHComponentTable.component_to_idx(component)
#             existing_list = idx_lookup[component_table_idx]
#             existing_list.append(Graph_Node(component, len(existing_list)))
#             idx_lookup[component_table_idx] = existing_list
#         return idx_lookup
#     
#     
#     def nxGraph(self):
#         plt.figure(figsize=(20, 20))
#         gx = nx.Graph()  # Initialize the graph
#         edges = []
#         for con in self.edges:
#             x  = (f"{con.v1n}-{con.v1i}", f"{con.v2n}-{con.v2i}")
#             edges.append(x)
#         # edges = [ for con in self.edges]  # Build edges
#         gx.add_edges_from(edges)  # Add edges to the graph correctly
#         return gx
#     
#     def show_graph(self):
#         plt.figure(figsize=(12, 8))  # Adjust the figure size as desired
#         gx = self.nxGraph()
#     
#         # Define custom labels for nodes to use only the part before the hyphen
#         custom_labels = {node: GHComponentTable.idx_to_component(int(node.split('-')[0])) for node in gx.nodes()}
#         nans = [custom_labels.items()]
#         nx.draw(gx, with_labels=True, labels=custom_labels, node_size=1000, font_size=10)
#         plt.show()
#     
#     
#     def save_graph(self, filename):
#         gx = self.nxGraph()
#         nx.write_graphml(gx, filename)
#         
#     def save_graph_png(self, filename):
#         gx = self.nxGraph()
#         custom_labels = {node: GHComponentTable.idx_to_component(int(node.split('-')[0])) for node in gx.nodes()}
#         nans = [custom_labels.items()]
#         nx.draw(gx, with_labels=True, labels=custom_labels, node_size=1000, font_size=10)
#         plt.savefig(filename + "png")
#     
#     def __str__(self):
#         
#         return f"{self.edges}"

# %%
class GHProcessor:
    def __init__(self, filepath, filename):
        self.filepath = filepath
        self.filename = filename
        self.doc = self.get_ghdoc(filepath, filename)
        self.canvas = Canvas(self.doc)
        self.canvas.initialize_components()
        self.graph = None
    
    @staticmethod
    def get_ghdoc(filepath, filename):
        ghfile = os.path.join(filepath, filename)
        if not os.path.exists(ghfile):
            print("This file does not exists:", ghfile)
            raise FileNotFoundError(ghfile)
        ghdocIO = Grasshopper.Kernel.GH_DocumentIO()
        ghdocIO.Open(ghfile)
        ghdoc = ghdocIO.Document
        return ghdoc

    def show_components(self):
        for component in self.canvas.components:
            print(component)

    def build_graph(self):
        self.graph = GHGraph(self.canvas)
        ic(self.graph.edges)
        # graph_name = self.filename.split(".")[0]
        # graph_location = os.path.join(self.filepath, graph_name)
        # # self.graph.save_graph()
        self.graph.show_graph()
        # # Adjust GHGraph to accept canvas and component_table as parameters

# %%
# %%time
filepath = os.getcwd()
filename = "test-BIG.gh"
ghp = GHProcessor(filepath, filename)
# ghp.show_components()
for obj in ghp.canvas.components:
    a, b = obj.get_connections()
    print((obj.global_idx, a))
# ghp.build_graph()
# Out:
# WARNING:root:COMPONENT Point,62460  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Point,62460 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Range,dee50  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Range,dee50 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Range,378d4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Range,378d4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,f64a4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,f64a4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,c4914  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,c4914 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Rotate,ad8b3  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Rotate,ad8b3 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,33c49  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,33c49 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Construct Domain,160d7  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Construct Domain,160d7 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,0969d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,0969d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Nurbs Curve,a1265  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Nurbs Curve,a1265 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Nurbs Curve,d8033  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Nurbs Curve,d8033 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,37597  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,37597 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Cross Product,2e417  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Cross Product,2e417 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,7b6f4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,7b6f4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Vector Display,2b3dc  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Vector Display,2b3dc DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Project Point,ee347  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Project Point,ee347 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode Tree,70659  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode Tree,70659 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,06ea4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,06ea4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve Closest Point,b51a2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve Closest Point,b51a2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Shatter,2d2b9  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Shatter,2d2b9 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT List Item,e073f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT List Item,e073f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Length,20010  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Length,20010 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Sort List,1c57c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Sort List,1c57c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,bb70a  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,bb70a DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Line,c0244  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Line,c0244 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Graph Mapper,3a25b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Graph Mapper,3a25b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,9fbac  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,9fbac DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Range,16c18  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Range,16c18 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Remap Numbers,cfcd0  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Remap Numbers,cfcd0 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Bounds,e2a86  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Bounds,e2a86 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Construct Domain,7ca89  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Construct Domain,7ca89 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,f361e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,f361e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,b371b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,b371b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Addition,960d6  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Addition,960d6 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,0ffd5  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,0ffd5 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Horizontal Frames,c6e19  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Horizontal Frames,c6e19 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct Plane,42ca5  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct Plane,42ca5 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Project Point,1dd79  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Project Point,1dd79 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,3480f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,3480f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Pi,fd135  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Pi,fd135 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,cbb74  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,cbb74 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Scale NU,a3c11  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Scale NU,a3c11 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT XY Plane,7331e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT XY Plane,7331e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Rotate Plane,8f00f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Rotate Plane,8f00f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,7acd8  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,7acd8 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,113f8  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,113f8 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,bdc06  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,bdc06 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,a3405  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,a3405 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,83850  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,83850 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,4bd67  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,4bd67 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,d6f75  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,d6f75 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Region Union,73083  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Region Union,73083 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT List Item,e4418  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT List Item,e4418 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Area,fce63  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Area,fce63 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Sort List,cfcca  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Sort List,cfcca DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Boundary Surfaces,7c6e7  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Boundary Surfaces,7c6e7 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Custom Preview,906ff  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Custom Preview,906ff DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,63519  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,63519 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT End Points,bf44e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT End Points,bf44e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,388f2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,388f2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode,c56be  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode,c56be DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Match Text,c8d8d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Match Text,c8d8d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,5c96c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,5c96c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,5a831  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,5a831 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Cull Pattern,88036  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Cull Pattern,88036 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Interpolate,1ac9f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Interpolate,1ac9f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode,18155  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode,18155 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,c8ade  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,c8ade DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Match Text,77e9b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Match Text,77e9b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,4385b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,4385b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Dispatch,4b805  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Dispatch,4b805 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,426cb  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,426cb DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,4a9fc  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,4a9fc DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,a47e3  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,a47e3 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,d6222  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,d6222 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,00e1b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,00e1b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Path Mapper,6d275  failed initial assignment of parameters: object does not implement IGH_Component
# WARNING:root:COMPONENT Path Mapper,6d275 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,746bf  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,746bf DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Path Mapper,6f03f  failed initial assignment of parameters: object does not implement IGH_Component
# WARNING:root:COMPONENT Path Mapper,6f03f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,a2e94  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,a2e94 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,93794  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,93794 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT End Points,f624c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT End Points,f624c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Project,09411  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Project,09411 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Merge,4aaa1  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Merge,4aaa1 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT XY Plane,23210  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT XY Plane,23210 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Line,0c261  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Line,0c261 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Merge,c799e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Merge,c799e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Join Curves,04899  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Join Curves,04899 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode Tree,3b7ce  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode Tree,3b7ce DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface,3245d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface,3245d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface,1d46e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface,1d46e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface,0327e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface,0327e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface,5eea2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface,5eea2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Interpolate,1bc79  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Interpolate,1bc79 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode Tree,f9c9a  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode Tree,f9c9a DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,2cf5d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,2cf5d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode Tree,0ec42  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode Tree,0ec42 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,2a64e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,2a64e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,87706  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,87706 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Merge,417cf  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Merge,417cf DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Join Curves,b2e68  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Join Curves,b2e68 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,c3568  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,c3568 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,dc016  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,dc016 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface Split,1998a  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface Split,1998a DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,6acdd  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,6acdd DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,5e99e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,5e99e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,7307c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,7307c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,009e0  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,009e0 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Reverse,3ff42  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Reverse,3ff42 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,b747c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,b747c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Extrude,14436  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Extrude,14436 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,cee3c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,cee3c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct Brep,1bc49  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct Brep,1bc49 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Pull Point,0433b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Pull Point,0433b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Larger Than,d3400  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Larger Than,d3400 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Multiplication,c4acf  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Multiplication,c4acf DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,46cca  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,46cca DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Sort List,a2a74  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Sort List,a2a74 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT List Item,de9c2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT List Item,de9c2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Cull Pattern,5de94  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Cull Pattern,5de94 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Graft Tree,349db  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Graft Tree,349db DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct,24f95  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct,24f95 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct,50399  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct,50399 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Point,1d263  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Point,1d263 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Mass Addition,d5fbd  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Mass Addition,d5fbd DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Equality,aa4b4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Equality,aa4b4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Boolean,bcb7e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Boolean,bcb7e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Gate Or,6d9e5  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Gate Or,6d9e5 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Colour Swatch,6e962  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Colour Swatch,6e962 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Merge,436fb  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Merge,436fb DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Brep Join,64dc6  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Brep Join,64dc6 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number,e3a8e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number,e3a8e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Point Cylindrical,c98a3  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Point Cylindrical,c98a3 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Colour Swatch,e33d2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Colour Swatch,e33d2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,f482c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,f482c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Evaluate Curve,454ef  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Evaluate Curve,454ef DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Custom Preview,4d65f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Custom Preview,4d65f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT XY Plane,7a687  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT XY Plane,7a687 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,e87b6  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,e87b6 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Point,62460  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Point,62460 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Range,dee50  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Range,dee50 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Range,378d4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Range,378d4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,f64a4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,f64a4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,c4914  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,c4914 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Rotate,ad8b3  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Rotate,ad8b3 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,33c49  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,33c49 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Construct Domain,160d7  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Construct Domain,160d7 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,0969d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,0969d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Nurbs Curve,a1265  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Nurbs Curve,a1265 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Nurbs Curve,d8033  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Nurbs Curve,d8033 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,37597  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,37597 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Cross Product,2e417  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Cross Product,2e417 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,7b6f4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,7b6f4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Vector Display,2b3dc  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Vector Display,2b3dc DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Project Point,ee347  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Project Point,ee347 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode Tree,70659  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode Tree,70659 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Entwine,06ea4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,06ea4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve Closest Point,b51a2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve Closest Point,b51a2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Shatter,2d2b9  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Shatter,2d2b9 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT List Item,e073f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT List Item,e073f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Length,20010  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Length,20010 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Sort List,1c57c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Sort List,1c57c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,bb70a  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,bb70a DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Line,c0244  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Line,c0244 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Graph Mapper,3a25b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Graph Mapper,3a25b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,9fbac  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,9fbac DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Range,16c18  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Range,16c18 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Remap Numbers,cfcd0  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Remap Numbers,cfcd0 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Bounds,e2a86  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Bounds,e2a86 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Construct Domain,7ca89  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Construct Domain,7ca89 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,f361e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,f361e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,b371b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,b371b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Addition,960d6  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Addition,960d6 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,0ffd5  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,0ffd5 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Horizontal Frames,c6e19  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Horizontal Frames,c6e19 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct Plane,42ca5  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct Plane,42ca5 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Project Point,1dd79  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Project Point,1dd79 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,3480f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,3480f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Pi,fd135  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Pi,fd135 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,cbb74  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,cbb74 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Scale NU,a3c11  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Scale NU,a3c11 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT XY Plane,7331e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT XY Plane,7331e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Rotate Plane,8f00f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Rotate Plane,8f00f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,7acd8  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,7acd8 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,113f8  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,113f8 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,bdc06  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,bdc06 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,a3405  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,a3405 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,83850  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,83850 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,4bd67  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,4bd67 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Loft,d6f75  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Loft,d6f75 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Region Union,73083  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Region Union,73083 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT List Item,e4418  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT List Item,e4418 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Area,fce63  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Area,fce63 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Sort List,cfcca  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Sort List,cfcca DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Boundary Surfaces,7c6e7  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Boundary Surfaces,7c6e7 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Custom Preview,906ff  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Custom Preview,906ff DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,63519  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,63519 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT End Points,bf44e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT End Points,bf44e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,388f2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,388f2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Explode,c56be  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Explode,c56be DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Match Text,c8d8d  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Match Text,c8d8d DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,5c96c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# ...
# WARNING:root:COMPONENT Join Curves,b2e68 DID NOT EXTRACT PARAMETERS, not added to components table
# DID NOT ADD Point
# DID NOT ADD Range
# DID NOT ADD Range
# DID NOT ADD Number Slider
# DID NOT ADD Number Slider
# DID NOT ADD Rotate
# DID NOT ADD Panel
# DID NOT ADD Construct Domain
# DID NOT ADD Number Slider
# DID NOT ADD Nurbs Curve
# DID NOT ADD Nurbs Curve
# DID NOT ADD Entwine
# DID NOT ADD Cross Product
# DID NOT ADD Unit Z
# DID NOT ADD Vector Display
# DID NOT ADD Project Point
# DID NOT ADD Explode Tree
# DID NOT ADD Entwine
# DID NOT ADD Curve Closest Point
# DID NOT ADD Shatter
# DID NOT ADD List Item
# DID NOT ADD Length
# DID NOT ADD Sort List
# DID NOT ADD Number Slider
# DID NOT ADD Line
# DID NOT ADD Graph Mapper
# DID NOT ADD Panel
# DID NOT ADD Range
# DID NOT ADD Remap Numbers
# DID NOT ADD Bounds
# DID NOT ADD Construct Domain
# DID NOT ADD Number Slider
# DID NOT ADD Unit Z
# DID NOT ADD Addition
# DID NOT ADD Number Slider
# DID NOT ADD Horizontal Frames
# DID NOT ADD Deconstruct Plane
# DID NOT ADD Project Point
# DID NOT ADD Number Slider
# DID NOT ADD Pi
# DID NOT ADD Number Slider
# DID NOT ADD Scale NU
# DID NOT ADD XY Plane
# DID NOT ADD Rotate Plane
# DID NOT ADD Number Slider
# DID NOT ADD Number Slider
# DID NOT ADD Number Slider
# DID NOT ADD Curve
# DID NOT ADD Move
# DID NOT ADD Loft
# DID NOT ADD Loft
# DID NOT ADD Region Union
# DID NOT ADD List Item
# DID NOT ADD Area
# DID NOT ADD Sort List
# DID NOT ADD Boundary Surfaces
# DID NOT ADD Custom Preview
# DID NOT ADD Unit Z
# DID NOT ADD End Points
# DID NOT ADD Curve
# DID NOT ADD Explode
# DID NOT ADD Match Text
# DID NOT ADD Panel
# DID NOT ADD Panel
# DID NOT ADD Cull Pattern
# DID NOT ADD Interpolate
# DID NOT ADD Explode
# DID NOT ADD Panel
# DID NOT ADD Match Text
# DID NOT ADD Panel
# DID NOT ADD Dispatch
# DID NOT ADD Curve
# DID NOT ADD Curve
# DID NOT ADD Entwine
# DID NOT ADD Loft
# DID NOT ADD Curve
# DID NOT ADD Path Mapper
# DID NOT ADD Loft
# DID NOT ADD Path Mapper
# DID NOT ADD Loft
# DID NOT ADD Move
# DID NOT ADD End Points
# DID NOT ADD Project
# DID NOT ADD Merge
# DID NOT ADD XY Plane
# DID NOT ADD Line
# DID NOT ADD Merge
# DID NOT ADD Join Curves
# DID NOT ADD Explode Tree
# DID NOT ADD Surface
# DID NOT ADD Surface
# DID NOT ADD Surface
# DID NOT ADD Surface
# DID NOT ADD Interpolate
# DID NOT ADD Explode Tree
# DID NOT ADD Curve
# DID NOT ADD Explode Tree
# DID NOT ADD Curve
# DID NOT ADD Curve
# DID NOT ADD Merge
# DID NOT ADD Join Curves
# DID NOT ADD Entwine
# DID NOT ADD Curve
# DID NOT ADD Surface Split
# DID NOT ADD Move
# DID NOT ADD Unit Z
# DID NOT ADD Number Slider
# DID NOT ADD Move
# DID NOT ADD Reverse
# DID NOT ADD Unit Z
# DID NOT ADD Extrude
# DID NOT ADD Unit Z
# DID NOT ADD Deconstruct Brep
# DID NOT ADD Pull Point
# DID NOT ADD Larger Than
# DID NOT ADD Multiplication
# DID NOT ADD Number Slider
# DID NOT ADD Sort List
# DID NOT ADD List Item
# DID NOT ADD Cull Pattern
# DID NOT ADD Graft Tree
# DID NOT ADD Deconstruct
# DID NOT ADD Deconstruct
# DID NOT ADD Point
# DID NOT ADD Mass Addition
# DID NOT ADD Equality
# DID NOT ADD Boolean
# DID NOT ADD Gate Or
# DID NOT ADD Colour Swatch
# DID NOT ADD Merge
# DID NOT ADD Brep Join
# DID NOT ADD Number
# DID NOT ADD Point Cylindrical
# DID NOT ADD Colour Swatch
# DID NOT ADD Panel
# DID NOT ADD Evaluate Curve
# DID NOT ADD Custom Preview
# DID NOT ADD XY Plane
# DID NOT ADD Panel
# DID NOT ADD Point
# DID NOT ADD Range
# DID NOT ADD Range
# DID NOT ADD Number Slider
# DID NOT ADD Number Slider
# DID NOT ADD Rotate
# DID NOT ADD Panel
# DID NOT ADD Construct Domain
# DID NOT ADD Number Slider
# DID NOT ADD Nurbs Curve
# DID NOT ADD Nurbs Curve
# DID NOT ADD Entwine
# DID NOT ADD Cross Product
# DID NOT ADD Unit Z
# DID NOT ADD Vector Display
# DID NOT ADD Project Point
# DID NOT ADD Explode Tree
# DID NOT ADD Entwine
# DID NOT ADD Curve Closest Point
# DID NOT ADD Shatter
# DID NOT ADD List Item
# DID NOT ADD Length
# DID NOT ADD Sort List
# DID NOT ADD Number Slider
# DID NOT ADD Line
# DID NOT ADD Graph Mapper
# DID NOT ADD Panel
# DID NOT ADD Range
# DID NOT ADD Remap Numbers
# DID NOT ADD Bounds
# DID NOT ADD Construct Domain
# DID NOT ADD Number Slider
# DID NOT ADD Unit Z
# DID NOT ADD Addition
# DID NOT ADD Number Slider
# DID NOT ADD Horizontal Frames
# DID NOT ADD Deconstruct Plane
# DID NOT ADD Project Point
# DID NOT ADD Number Slider
# DID NOT ADD Pi
# DID NOT ADD Number Slider
# DID NOT ADD Scale NU
# DID NOT ADD XY Plane
# DID NOT ADD Rotate Plane
# DID NOT ADD Number Slider
# DID NOT ADD Number Slider
# DID NOT ADD Number Slider
# DID NOT ADD Curve
# DID NOT ADD Move
# DID NOT ADD Loft
# DID NOT ADD Loft
# DID NOT ADD Region Union
# DID NOT ADD List Item
# DID NOT ADD Area
# DID NOT ADD Sort List
# DID NOT ADD Boundary Surfaces
# DID NOT ADD Custom Preview
# DID NOT ADD Unit Z
# DID NOT ADD End Points
# DID NOT ADD Curve
# DID NOT ADD Explode
# DID NOT ADD Match Text
# DID NOT ADD Panel
# DID NOT ADD Panel
# DID NOT ADD Cull Pattern
# DID NOT ADD Interpolate
# DID NOT ADD Explode
# DID NOT ADD Panel
# DID NOT ADD Match Text
# DID NOT ADD Panel
# DID NOT ADD Dispatch
# DID NOT ADD Curve
# DID NOT ADD Curve
# DID NOT ADD Entwine
# DID NOT ADD Loft
# DID NOT ADD Curve
# DID NOT ADD Path Mapper
# DID NOT ADD Loft
# DID NOT ADD Path Mapper
# DID NOT ADD Loft
# DID NOT ADD Move
# DID NOT ADD End Points
# DID NOT ADD Project
# DID NOT ADD Merge
# DID NOT ADD XY Plane
# DID NOT ADD Line
# DID NOT ADD Merge
# DID NOT ADD Join Curves
# DID NOT ADD Explode Tree
# DID NOT ADD Surface
# DID NOT ADD Surface
# DID NOT ADD Surface
# DID NOT ADD Surface
# DID NOT ADD Interpolate
# DID NOT ADD Explode Tree
# DID NOT ADD Curve
# DID NOT ADD Explode Tree
# DID NOT ADD Curve
# DID NOT ADD Curve
# DID NOT ADD Merge
# WARNING:root:COMPONENT Entwine,c3568  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Entwine,c3568 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Curve,dc016  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Curve,dc016 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Surface Split,1998a  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Surface Split,1998a DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,6acdd  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,6acdd DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,5e99e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,5e99e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,7307c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,7307c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Move,009e0  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Move,009e0 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Reverse,3ff42  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Reverse,3ff42 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,b747c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,b747c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Extrude,14436  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Extrude,14436 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Unit Z,cee3c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Unit Z,cee3c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct Brep,1bc49  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct Brep,1bc49 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Pull Point,0433b  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Pull Point,0433b DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Larger Than,d3400  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Larger Than,d3400 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Multiplication,c4acf  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Multiplication,c4acf DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number Slider,46cca  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number Slider,46cca DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Sort List,a2a74  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Sort List,a2a74 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT List Item,de9c2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT List Item,de9c2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Cull Pattern,5de94  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Cull Pattern,5de94 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Graft Tree,349db  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Graft Tree,349db DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct,24f95  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct,24f95 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Deconstruct,50399  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Deconstruct,50399 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Point,1d263  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Point,1d263 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Mass Addition,d5fbd  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Mass Addition,d5fbd DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Equality,aa4b4  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Equality,aa4b4 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Boolean,bcb7e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Boolean,bcb7e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Gate Or,6d9e5  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Gate Or,6d9e5 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Colour Swatch,6e962  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Colour Swatch,6e962 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Merge,436fb  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Merge,436fb DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Brep Join,64dc6  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Brep Join,64dc6 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Number,e3a8e  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Number,e3a8e DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Point Cylindrical,c98a3  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Point Cylindrical,c98a3 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Colour Swatch,e33d2  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Colour Swatch,e33d2 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,f482c  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,f482c DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Evaluate Curve,454ef  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Evaluate Curve,454ef DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Custom Preview,4d65f  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Custom Preview,4d65f DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT XY Plane,7a687  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT XY Plane,7a687 DID NOT EXTRACT PARAMETERS, not added to components table
# WARNING:root:COMPONENT Panel,e87b6  failed initial assignment of parameters: __init__() missing 1 required positional argument: 'canvas'
# WARNING:root:COMPONENT Panel,e87b6 DID NOT EXTRACT PARAMETERS, not added to components table
# DID NOT ADD Join Curves
# DID NOT ADD Entwine
# DID NOT ADD Curve
# DID NOT ADD Surface Split
# DID NOT ADD Move
# DID NOT ADD Unit Z
# DID NOT ADD Number Slider
# DID NOT ADD Move
# DID NOT ADD Reverse
# DID NOT ADD Unit Z
# DID NOT ADD Extrude
# DID NOT ADD Unit Z
# DID NOT ADD Deconstruct Brep
# DID NOT ADD Pull Point
# DID NOT ADD Larger Than
# DID NOT ADD Multiplication
# DID NOT ADD Number Slider
# DID NOT ADD Sort List
# DID NOT ADD List Item
# DID NOT ADD Cull Pattern
# DID NOT ADD Graft Tree
# DID NOT ADD Deconstruct
# DID NOT ADD Deconstruct
# DID NOT ADD Point
# DID NOT ADD Mass Addition
# DID NOT ADD Equality
# DID NOT ADD Boolean
# DID NOT ADD Gate Or
# DID NOT ADD Colour Swatch
# DID NOT ADD Merge
# DID NOT ADD Brep Join
# DID NOT ADD Number
# DID NOT ADD Point Cylindrical
# DID NOT ADD Colour Swatch
# DID NOT ADD Panel
# DID NOT ADD Evaluate Curve
# DID NOT ADD Custom Preview
# DID NOT ADD XY Plane
# DID NOT ADD Panel
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\AppData\Local\Temp\ipykernel_27972\2750328340.py in get_connections(self)
#      41
#      42         # Handle connections to recipients from this component's output parameters
# ---> 43         for i, oparam in enumerate(self.oparams):  # Iterate over output parameters
#      44             if oparam.recipients:  # Ensure there are recipients to consider
#      45                 for r in oparam.recipients:
#
# TypeError: 'NoneType' object is not iterable
